# %% [markdown]
# #1. 배깅(bagging)
# > 배깅은 같은 알고리즘으로 여러 개의 분류기를 만들어서 보팅으로 최종 결정하는 알고리즘이다.

# %% [markdown]
# #2. 랜덤 포레스트
# > 배깅의 대표적인 알고리즘으로 앙상블 알고리즘 중 비교적 빠른 수행 속도를 가지고 있으며 다양한 영역에서 높은 예측 성능을 보이고 있다. 랜덤 포레스트의 기반 알고리즘은 결정트리로 쉽고 직관적인 장점을 그대로 가지고 있다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 랜덤 포레스트는 여러 개의 결정 트리 분류기가 전체 데이터에서 배깅 방식으로 각자의 데이터를 샘플링해 개별적으로 학습을 수행한 뒤 최종적으로 모든 분류기가 보팅을 통해 예측 결정을 하게 된다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 랜텀 포레스트의 각 분류기에 사용되는 데이터는 하나의 데이터에서 중복된 데이터의 모음으로 이를 부트스트래핑(bootstrapping) 분할 방식 이라고 한다.
#
# > Bagging은 Bootstrap aggregating의 약자로 부분 부분 나누어진 데이터의 집합 정도로 이해하면 된다.
#
# > 통계학에서의 부트스트랩은 여러 개의 작은 데이터 셋을 임의로 만들어 개별 평균의 분포도를 측정하는 목적으로 샘플링하는 방법이다.
