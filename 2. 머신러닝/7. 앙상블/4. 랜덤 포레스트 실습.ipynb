# %% [markdown]
# #1. 파일 읽기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

filepath = '/content/drive/MyDrive/3. 머신러닝/6. 앙상블/data/features_dup.txt'
df = pd.read_csv(filepath, names=['index', 'name'])
df.head()
# Out:
#    index               name
# 0      1  tBodyAcc-mean()-X
# 1      2  tBodyAcc-mean()-Y
# 2      3  tBodyAcc-mean()-Z
# 3      4   tBodyAcc-std()-X
# 4      5   tBodyAcc-std()-Y

# %%
path = '/content/drive/MyDrive/3. 머신러닝/6. 앙상블/data'
# 학습 피처 데이터세트와 테스트 피처 데이터를 데이터프레임으로 로딩
# 컬럼명은 feature_name 적용
X_train = pd.read_csv(path+'/train/X_train.txt', sep='\s+', names=df['name'])
X_test = pd.read_csv(path+'/test/X_test.txt', sep='\s+', names=df['name'])

# 학습 레이블과 테스트 레이블 데이터를 데이터 프레임으로 로딩, 컬럼명은 action으로 부여
y_train = pd.read_csv(path+'/train/y_train.txt', sep='\s+', names=['action'])
y_test = pd.read_csv(path+'/test/y_test.txt', sep='\s+', names=['action'])

# %% [markdown]
# #2. 모델 만들기

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

rf = RandomForestClassifier(random_state=100) 
rf.fit(X_train, y_train.values.reshape(-1)) 
y_pred = rf.predict(X_test) 
print("rf acc : {}".format(accuracy_score(y_test, y_pred)))
# Out:
# rf acc : 0.9321343739395996

# %% [markdown]
# #3. 튜닝

# %%
from sklearn.model_selection import GridSearchCV

def get_best_hyper_paramerter():
  params =  {
    'n_estimators' : n_estimators_list,
    'max_depth' : max_depth_list,
    'min_samples_leaf' : min_samples_leaf_list,
    'min_samples_split' : min_samples_split
  }

  grid_cv = GridSearchCV(rf, param_grid=params, scoring='accuracy', cv=5)
  grid_cv.fit(X_train, y_train.values.reshape(-1))
  print('Best Score: ', grid_cv.best_score_)
  print('Best Hyper Parameter: ', grid_cv.best_params_)

# %%
# 분류기를 100개로 지정
n_estimators_list =  [100]
max_depth_list =  range(5, 15, 5)
min_samples_leaf_list = range(5, 15, 5)
min_samples_split = range(5, 15, 5)

get_best_hyper_paramerter()
# Out:
# Best Score:  0.9232909261597229
# Best Hyper Parameter:  {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}

# %% [markdown]
# > 5분 소요

# %%
n_estimators_list =  [300]
max_depth_list =  range(5, 15, 5)
min_samples_leaf_list = range(5, 15, 5)
min_samples_split = range(5, 15, 5)

get_best_hyper_paramerter()
# Out:
# Best Score:  0.9234257781970708
# Best Hyper Parameter:  {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 300}

# %% [markdown]
# > 13분정도 걸림

# %%
n_estimators_list =  [500]
max_depth_list =  [10]
min_samples_leaf_list = [10]
min_samples_split = [5]

get_best_hyper_paramerter()
# Out:
# Best Score:  0.9222013808922618
# Best Hyper Parameter:  {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 500}

# %% [markdown]
# 4분 소요

# %%
n_estimators_list =  [350]
max_depth_list =  [10]
min_samples_leaf_list = [10]
min_samples_split = [5]

get_best_hyper_paramerter()
# Out:
# Best Score:  0.9236976095672803
# Best Hyper Parameter:  {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 350}

# %% [markdown]
# >3분 소요

# %%
n_estimators_list =  [400]
max_depth_list =  [10]
min_samples_leaf_list = [10]
min_samples_split = [5]

get_best_hyper_paramerter()
# Out:
# Best Score:  0.9231533918802055
# Best Hyper Parameter:  {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 400}

# %% [markdown]
# > 3분 소요

# %%
n_estimators_list =  range(350, 400, 10)
max_depth_list =  [10]
min_samples_leaf_list = [10]
min_samples_split = [5]

get_best_hyper_paramerter()
# Out:
# Best Score:  0.9241056803414771
# Best Hyper Parameter:  {'max_depth': 10, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 360}
