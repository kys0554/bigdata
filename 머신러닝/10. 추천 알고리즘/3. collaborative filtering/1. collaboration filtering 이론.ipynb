# %% [markdown]
# #1. 협업필터링
# > 사용자가 아이템에 매긴 평점 정보나 상품 구매 이력과 같은 사용자 행동 양식(User Behavior)만을 기반으로 추천을 수행하는 것이 협업필터링이다.
#
# >협업 필터링의 주 목적은 축적된 사용자 행동 패턴을 기반으로 사용자가 아직 평가하지 않은 아이템을 예측 평가(Predicted Rating)하는 방법이다.

# %% [markdown]
# ##1.1 협업 필터링 종류

# %% [markdown]
# ###1.1.1 최근접 이웃 방식 - 사용자 기반
# >사용자가 구매한 상품과 비슷한 구매 패턴을 가진 다른 구매자의 상품 추천

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 사용자 A와 사용자 B는 같은 영화에 대해 비슷한 평점을 매겼다. 따라서 사용자 A에게는 사용자 B가 높게 평가한 프로메테우스를 추천해 주는 것이 좋다.

# %% [markdown]
# ###1.1.2 최근접 이웃 방식 - 아이템 기반
# >같은 상품을 구매한 사용자가 구매한 상품 중 내가 사지 않은 상품을 추천

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > 다트 나이트를 높게 평가한 사람들이 프로메테우스 역시 높게 평가 했음으로 사용자 D에게는 스타워즈보다 프로메테우스를 추천해 주는 것이 좋다.
